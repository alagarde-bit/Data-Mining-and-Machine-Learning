# %% [markdown]
# <a href="https://colab.research.google.com/github/alagarde-bit/Data-Mining-and-Machine-Learning/blob/main/lab09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 09 Regression
# ## CSC 401 Lab
# ## Alex Lagarde
# ### 3/10/21

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import operator 
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1XHF2E7uXPqXSmGi2X1E9_o9VmIh89bfV')
df.head(5)
# Out:
#           x          y  is_train
# 0  0.000799   1.699337       1.0
# 1  0.010214  -0.436091       1.0
# 2  0.071439  -1.873174       1.0
# 3  0.076680  15.854541       1.0
# 4  0.115109  -0.831285       1.0

# %%
# Splitting data into training and testing data, converting to numpy arrays, and reshaping
xtrain = df['x'][df['is_train'] == 1.0].values.reshape((-1,1))
ytrain = df['y'][df['is_train'] == 1.0].values.reshape((-1,1))
xtest = df['x'][df['is_train'] == 0.0].values.reshape((-1,1))
ytest = df['x'][df['is_train'] == 0.0].values.reshape((-1,1))

# %%
# Scatterplot of training data
plt.scatter(xtrain, ytrain, marker='o', c = 'blue', alpha = 0.2)
plt.title('Scatterplot of Predictor vs Response with Training Data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Fitting polynomial regression, testing data predictions, and MAE scores
poly_model = make_pipeline(PolynomialFeatures(1), LinearRegression())
yfit = poly_model.fit(xtrain, ytrain)
ypred = poly_model.predict(xtest)
MAE = mean_absolute_error(ytest, ypred)

poly_model2 =  make_pipeline(PolynomialFeatures(2), LinearRegression())
yfit2 = poly_model2.fit(xtrain, ytrain)
ypred2 = poly_model2.predict(xtest)
MAE2 = mean_absolute_error(ytest, ypred2)

poly_model3 = make_pipeline(PolynomialFeatures(3), LinearRegression())
yfit3 = poly_model3.fit(xtrain, ytrain)
ypred3 = poly_model3.predict(xtest)
MAE3 = mean_absolute_error(ytest, ypred3)

poly_model4 =  make_pipeline(PolynomialFeatures(4), LinearRegression())
yfit4 = poly_model4.fit(xtrain, ytrain)
ypred4 = poly_model4.predict(xtest)
MAE4 = mean_absolute_error(ytest, ypred4)

poly_model5 =  make_pipeline(PolynomialFeatures(5), LinearRegression())
yfit5 = poly_model5.fit(xtrain, ytrain)
ypred5 = poly_model5.predict(xtest)
MAE5 = mean_absolute_error(ytest, ypred5)

# %%
# Evaluating Models
models = {'1st Degree Polynomial': MAE, 
          '2nd Degree Polynomial': MAE2,
          '3rd Degree Polynomial' : MAE3, 
          '4th Degree Polynomial' : MAE4,
          '5th Degree Polynomial' : MAE5}
sorted_MAE = sorted(models.items(), key=operator.itemgetter(1))
for i in sorted_MAE:
  print(i)
# Out:
# ('1st Degree Polynomial', 2.7042225267968876)
# ('2nd Degree Polynomial', 3.6447570490634944)
# ('3rd Degree Polynomial', 3.6965929519073395)
# ('4th Degree Polynomial', 4.17116194805545)
# ('5th Degree Polynomial', 4.277425727067697)

# %% [markdown]
# The first degree polynomial is the strongest model with a mean absolute error of 2.7042

# %%
plt.scatter(xtrain, ytrain, marker= 'o', c = 'blue', alpha = 0.2)
plt.plot(xtest, ypred, c = 'red')
plt.title('Scatterplot of Predictor vs Response with Best Fit Line')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
